# %%
name_of_state=['Andaman and Nicobar'
,'Andhra Pradesh'
, 'Arunachal Pradesh'
, 'Assam'
, 'Bihar'
, 'Chandigarh'
, 'Chhattisgarh'
, 'Dadra and Nagar Haveli and Daman'
, 'Delhi'
, 'Goa'
, 'Gujarat'
, 'Haryana'
, 'Himachal Pradesh'
, 'Jammu and Kashmir'
, 'Jharkhand'
, 'Karnataka'
, 'Kerala'
, 'Ladakh'
, 'Lakshadweep'
, 'Madhya Pradesh'
, 'Maharashtra'
, 'Manipur'
, 'Meghalaya'
, 'Mizoram'
, 'Nagaland'
, 'Odisha'
, 'Puducherry'
, 'Punjab'
, 'Rajasthan'
, 'Sikkim'
, 'Tamil Nadu'
, 'Telengana'
, 'Tripura'
, 'Uttar Pradesh'
, 'Uttarakhand'
, 'West Bengal'
]

# %%
name_of_state
# Out:
# ['Andaman and Nicobar',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra and Nagar Haveli and Daman',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telengana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %%
no_of_infected=[194
,40646
,609
,20646
,23589
,660
,4964
,585
,120107
,3304
,46430
,24797
,1417
,12757
,4921
,55115
,11066
,1151
,0
,21081
,292589
,1800
,403
,282
,956
,16110
,1832
,9442
,27789
,266
,160907
,42496
,2366
,45163
,4102
,38011]

# %%
no_of_infected
# Out:
# [194,
#  40646,
#  609,
#  20646,
#  23589,
#  660,
#  4964,
#  585,
#  120107,
#  3304,
#  46430,
#  24797,
#  1417,
#  12757,
#  4921,
#  55115,
#  11066,
#  1151,
#  0,
#  21081,
#  292589,
#  1800,
#  403,
#  282,
#  956,
#  16110,
#  1832,
#  9442,
#  27789,
#  266,
#  160907,
#  42496,
#  2366,
#  45163,
#  4102,
#  38011]

# %%
no_of_recovered=[142
,20298
,175
,14105
,14621
,480
,3512
,401
,99301
,1946
,32973
,18718
,1024
,6558
,2570
,20757
,4995
,973
,0
,14514
,160357
,1163
,66
,160
,405
,11330
,1014
,6373
,20626
,90
,110807
,28705
,1684
,27634
,3021
,22253]

# %%
no_of_recovered
# Out:
# [142,
#  20298,
#  175,
#  14105,
#  14621,
#  480,
#  3512,
#  401,
#  99301,
#  1946,
#  32973,
#  18718,
#  1024,
#  6558,
#  2570,
#  20757,
#  4995,
#  973,
#  0,
#  14514,
#  160357,
#  1163,
#  66,
#  160,
#  405,
#  11330,
#  1014,
#  6373,
#  20626,
#  90,
#  110807,
#  28705,
#  1684,
#  27634,
#  3021,
#  22253]

# %%
for i in range(len(name_of_state)):
    print ({name_of_state[i]:no_of_infected[i]})
# Out:
# {'Andaman and Nicobar': 194}
# {'Andhra Pradesh': 40646}
# {'Arunachal Pradesh': 609}
# {'Assam': 20646}
# {'Bihar': 23589}
# {'Chandigarh': 660}
# {'Chhattisgarh': 4964}
# {'Dadra and Nagar Haveli and Daman': 585}
# {'Delhi': 120107}
# {'Goa': 3304}
# {'Gujarat': 46430}
# {'Haryana': 24797}
# {'Himachal Pradesh': 1417}
# {'Jammu and Kashmir': 12757}
# {'Jharkhand': 4921}
# {'Karnataka': 55115}
# {'Kerala': 11066}
# {'Ladakh': 1151}
# {'Lakshadweep': 0}
# {'Madhya Pradesh': 21081}
# {'Maharashtra': 292589}
# {'Manipur': 1800}
# {'Meghalaya': 403}
# {'Mizoram': 282}
# {'Nagaland': 956}
# {'Odisha': 16110}
# {'Puducherry': 1832}
# {'Punjab': 9442}
# {'Rajasthan': 27789}
# {'Sikkim': 266}
# {'Tamil Nadu': 160907}
# {'Telengana': 42496}
# {'Tripura': 2366}
# {'Uttar Pradesh': 45163}
# {'Uttarakhand': 4102}
# {'West Bengal': 38011}

# %%
population=(380581
,49577103
,1383727
,31205576
,104099452
,1055450
,25545198
,585764
,16787941
,1458545
,60439692
,25351462
,6864602
,12267032
,32988134
,61095297
,33406061
,274000
,64473
,72626809
,112374333
,2570390
,2966889
,1097206
,1978502
,41974219
,1247953
,27743338
,68548437
,610577
,72147030
,35003674
,3673917
,199812341
,10086292
,91276115
)

# %%
population
# Out:
# (380581,
#  49577103,
#  1383727,
#  31205576,
#  104099452,
#  1055450,
#  25545198,
#  585764,
#  16787941,
#  1458545,
#  60439692,
#  25351462,
#  6864602,
#  12267032,
#  32988134,
#  61095297,
#  33406061,
#  274000,
#  64473,
#  72626809,
#  112374333,
#  2570390,
#  2966889,
#  1097206,
#  1978502,
#  41974219,
#  1247953,
#  27743338,
#  68548437,
#  610577,
#  72147030,
#  35003674,
#  3673917,
#  199812341,
#  10086292,
#  91276115)

# %%
no_of_deaths=(0
,534
,3
,51
,201
,11
,23
,2
,3571
,21
,2106
,327
,11
,231
,46
,1147
,38
,1
,0
,697
,11452
,0
,2
,0
,0
,83
,25
,239
,546
,0
,2315
,403
,3
,1084
,51
,1049
)

# %%
no_of_deaths
# Out:
# (0,
#  534,
#  3,
#  51,
#  201,
#  11,
#  23,
#  2,
#  3571,
#  21,
#  2106,
#  327,
#  11,
#  231,
#  46,
#  1147,
#  38,
#  1,
#  0,
#  697,
#  11452,
#  0,
#  2,
#  0,
#  0,
#  83,
#  25,
#  239,
#  546,
#  0,
#  2315,
#  403,
#  3,
#  1084,
#  51,
#  1049)

# %%
def CMR(deaths,total_poppulation):
    CMR=(deaths/total_poppulation)*100000
    print("The Crude Mortality Rate ={}%".format(CMR))

# %%
for i in range (len(name_of_state)):
    print(name_of_state[i])
    CMR(no_of_deaths[i],population[i])
# Out:
# Andaman and Nicobar
# The Crude Mortality Rate =0.0%
# Andhra Pradesh
# The Crude Mortality Rate =1.0771101328772679%
# Arunachal Pradesh
# The Crude Mortality Rate =0.2168057716587159%
# Assam
# The Crude Mortality Rate =0.16343233017073616%
# Bihar
# The Crude Mortality Rate =0.19308458991695746%
# Chandigarh
# The Crude Mortality Rate =1.0422094841063054%
# Chhattisgarh
# The Crude Mortality Rate =0.0900364913985008%
# Dadra and Nagar Haveli and Daman
# The Crude Mortality Rate =0.34143443434557263%
# Delhi
# The Crude Mortality Rate =21.271220812605904%
# Goa
# The Crude Mortality Rate =1.4397910246169985%
# Gujarat
# The Crude Mortality Rate =3.4844651425424202%
# Haryana
# The Crude Mortality Rate =1.289866438472069%
# Himachal Pradesh
# The Crude Mortality Rate =0.16024235636676387%
# Jammu and Kashmir
# The Crude Mortality Rate =1.8830960903990468%
# Jharkhand
# The Crude Mortality Rate =0.13944408010468248%
# Karnataka
# The Crude Mortality Rate =1.8773949163386503%
# ...

# %%
no_of_active=(52
,19814
,431
,6490
,8767
,169
,1429
,182
,17235
,1337
,11351
,5752
,382
,5968
,2305
,33211
,6033
,177
,0
,5870
,120780
,637
,335
,122
,551
,4697
,793
,2830
,6617
,176
,47785
,13388
,679
,16445
,1030
,14709
)

# %%
no_of_active
# Out:
# (52,
#  19814,
#  431,
#  6490,
#  8767,
#  169,
#  1429,
#  182,
#  17235,
#  1337,
#  11351,
#  5752,
#  382,
#  5968,
#  2305,
#  33211,
#  6033,
#  177,
#  0,
#  5870,
#  120780,
#  637,
#  335,
#  122,
#  551,
#  4697,
#  793,
#  2830,
#  6617,
#  176,
#  47785,
#  13388,
#  679,
#  16445,
#  1030,
#  14709)

# %%
def IFR(deaths,infected):
    if(infected>0):
        IFR=(deaths/infected)*100
        print("The IFR is ={}%".format(IFR))

# %%
for i in range (len(name_of_state)):
    print(name_of_state[i])
    IFR(no_of_deaths[i],no_of_infected[i])
# Out:
# Andaman and Nicobar
# The IFR is =0.0%
# Andhra Pradesh
# The IFR is =1.3137824140136791%
# Arunachal Pradesh
# The IFR is =0.49261083743842365%
# Assam
# The IFR is =0.24702121476315023%
# Bihar
# The IFR is =0.8520920768154648%
# Chandigarh
# The IFR is =1.6666666666666667%
# Chhattisgarh
# The IFR is =0.46333601933924257%
# Dadra and Nagar Haveli and Daman
# The IFR is =0.3418803418803419%
# Delhi
# The IFR is =2.9731822458308006%
# Goa
# The IFR is =0.6355932203389831%
# Gujarat
# The IFR is =4.535860435063537%
# Haryana
# The IFR is =1.3187079082147033%
# Himachal Pradesh
# The IFR is =0.776287932251235%
# Jammu and Kashmir
# The IFR is =1.8107705573410675%
# Jharkhand
# The IFR is =0.9347693558219874%
# Karnataka
# The IFR is =2.0811031479633493%
# Kerala
# The IFR is =0.34339418037231156%
# Ladakh
# The IFR is =0.08688097306689835%
# Lakshadweep
# Madhya Pradesh
# The IFR is =3.3062947678003893%
# Maharashtra
# The IFR is =3.9140227417982216%
# Manipur
# The IFR is =0.0%
# ...

# %%
def total_infected(active,deaths,recovered):
        total_infected=(active+deaths+recovered)
        print(total_infected)

# %%
for i in range(len(name_of_state)):
    total_infected(no_of_active[i],no_of_deaths[i],no_of_recovered[i])
# Out:
# 194
# 40646
# 609
# 20646
# 23589
# 660
# 4964
# 585
# 120107
# 3304
# 46430
# 24797
# 1417
# 12757
# 4921
# 55115
# 11066
# 1151
# 0
# 21081
# 292589
# 1800
# 403
# 282
# 956
# 16110
# 1832
# 9442
# 27789
# 266
# 160907
# 42496
# 2366
# 45163
# 4102
# 38011
